# %%
import pandas as pd
import os
import numpy as np

# %%
data19=pd.read_csv('2019.csv')
data18=pd.read_csv('2018.csv')
data17=pd.read_csv('2017.csv')
data16=pd.read_csv('2016.csv')
data15=pd.read_csv('2015.csv')
data20=pd.read_csv('2020.csv')
data21=pd.read_csv('2021.csv')
concated=pd.read_csv('concated.csv')

# %%
data21
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
data21.drop(data21.columns.difference(['Country name','Ladder score','Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption']), 1, inplace=True)

# %%
data21['year']='2021'

# %%
data21.rename(columns = {'Ladder score':'Score'}, inplace = True)

# %%
data21
# Out:
#     Country name  Score  Explained by: Log GDP per capita  \
# 0        Finland  7.842                             1.446
# 1        Denmark  7.620                             1.502
# 2    Switzerland  7.571                             1.566
# 3        Iceland  7.554                             1.482
# 4    Netherlands  7.464                             1.501
# ..           ...    ...                               ...
# 144      Lesotho  3.512                             0.451
# 145     Botswana  3.467                             1.099
# 146       Rwanda  3.415                             0.364
# 147     Zimbabwe  3.145                             0.457
# 148  Afghanistan  2.523                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# ...

# %%
data20.drop(data20.columns.difference(['Country name','Ladder score','Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption']), 1, inplace=True)

# %%
data20.rename(columns = {'Ladder score':'Score'}, inplace = True)

# %%
data20
# Out:
#                  Country name   Score  Explained by: Log GDP per capita  \
# 0                     Finland  7.8087                          1.285190
# 1                     Denmark  7.6456                          1.326949
# 2                 Switzerland  7.5599                          1.390774
# 3                     Iceland  7.5045                          1.326502
# 4                      Norway  7.4880                          1.424207
# ..                        ...     ...                               ...
# 148  Central African Republic  3.4759                          0.041072
# 149                    Rwanda  3.3123                          0.343243
# 150                  Zimbabwe  3.2992                          0.425564
# 151               South Sudan  2.8166                          0.289083
# 152               Afghanistan  2.5669                          0.300706
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %%
data20['year']='2020'

# %%
data20
# Out:
#                  Country name   Score  Explained by: Log GDP per capita  \
# 0                     Finland  7.8087                          1.285190
# 1                     Denmark  7.6456                          1.326949
# 2                 Switzerland  7.5599                          1.390774
# 3                     Iceland  7.5045                          1.326502
# 4                      Norway  7.4880                          1.424207
# ..                        ...     ...                               ...
# 148  Central African Republic  3.4759                          0.041072
# 149                    Rwanda  3.3123                          0.343243
# 150                  Zimbabwe  3.2992                          0.425564
# 151               South Sudan  2.8166                          0.289083
# 152               Afghanistan  2.5669                          0.300706
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %%
gdpname='Explained by: Log GDP per capita'
socialname='Explained by: Social support'
lifeexpectancyname='Explained by: Healthy life expectancy'
freedomname='Explained by: Freedom to make life choices'
generocityname='Explained by: Generosity'
corruptionname='Explained by: Perceptions of corruption'

# %%
data19.drop(data19.columns.difference(['Country or region','Score', 'GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices','Generosity', 'Perceptions of corruption']), 1, inplace=True)

# %%
data19
# Out:
#             Country or region  Score  GDP per capita  Social support  \
# 0                     Finland  7.769           1.340           1.587
# 1                     Denmark  7.600           1.383           1.573
# 2                      Norway  7.554           1.488           1.582
# 3                     Iceland  7.494           1.380           1.624
# 4                 Netherlands  7.488           1.396           1.522
# ..                        ...    ...             ...             ...
# 151                    Rwanda  3.334           0.359           0.711
# 152                  Tanzania  3.231           0.476           0.885
# 153               Afghanistan  3.203           0.350           0.517
# 154  Central African Republic  3.083           0.026           0.000
# 155               South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
data19.rename(columns = {'Country or region':'Country name', 'GDP per capita':gdpname, 'Social support':socialname, 'Healthy life expectancy':lifeexpectancyname, 'Freedom to make life choices':freedomname,'Generosity':generocityname,'Perceptions of corruption':corruptionname}, inplace = True) 
data19['year']='2019'

# %%
data19
# Out:
#                  Country name  Score  Explained by: Log GDP per capita  \
# 0                     Finland  7.769                             1.340
# 1                     Denmark  7.600                             1.383
# 2                      Norway  7.554                             1.488
# 3                     Iceland  7.494                             1.380
# 4                 Netherlands  7.488                             1.396
# ..                        ...    ...                               ...
# 151                    Rwanda  3.334                             0.359
# 152                  Tanzania  3.231                             0.476
# 153               Afghanistan  3.203                             0.350
# 154  Central African Republic  3.083                             0.026
# 155               South Sudan  2.853                             0.306
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %%
data18.drop(data18.columns.difference(['Country or region','Score', 'GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices','Generosity', 'Perceptions of corruption']), 1, inplace=True)
data18.rename(columns = {'Country or region':'Country name', 'GDP per capita':gdpname, 'Social support':socialname, 'Healthy life expectancy':lifeexpectancyname, 'Freedom to make life choices':freedomname,'Generosity':generocityname,'Perceptions of corruption':corruptionname}, inplace = True) 
data18['year']='2018'

# %%
data18
# Out:
#                  Country name  Score  Explained by: Log GDP per capita  \
# 0                     Finland  7.632                             1.305
# 1                      Norway  7.594                             1.456
# 2                     Denmark  7.555                             1.351
# 3                     Iceland  7.495                             1.343
# 4                 Switzerland  7.487                             1.420
# ..                        ...    ...                               ...
# 151                     Yemen  3.355                             0.442
# 152                  Tanzania  3.303                             0.455
# 153               South Sudan  3.254                             0.337
# 154  Central African Republic  3.083                             0.024
# 155                   Burundi  2.905                             0.091
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %%
data17.drop(data17.columns.difference(['Country','Happiness.Score','Economy..GDP.per.Capita.','Family','Health..Life.Expectancy.','Freedom', 'Generosity', 'Trust..Government.Corruption.']), 1, inplace=True)
data17.rename(columns = {'Country':'Country name','Happiness.Score':'Score','Economy..GDP.per.Capita.':gdpname, 'Family':socialname,'Health..Life.Expectancy.':lifeexpectancyname, 'Freedom':freedomname, 'Generosity':generocityname,'Trust..Government.Corruption.':corruptionname }, inplace = True)
data17['year']='2017'

# %%
data17
# Out:
#                  Country name  Score  Explained by: Log GDP per capita  \
# 0                      Norway  7.537                          1.616463
# 1                     Denmark  7.522                          1.482383
# 2                     Iceland  7.504                          1.480633
# 3                 Switzerland  7.494                          1.564980
# 4                     Finland  7.469                          1.443572
# ..                        ...    ...                               ...
# 150                    Rwanda  3.471                          0.368746
# 151                     Syria  3.462                          0.777153
# 152                  Tanzania  3.349                          0.511136
# 153                   Burundi  2.905                          0.091623
# 154  Central African Republic  2.693                          0.000000
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %%
data16.drop(data16.columns.difference(['Country','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom', 'Generosity', 'Trust (Government Corruption)']), 1, inplace=True)
data16.rename(columns = {'Country':'Country name','Happiness Score':'Score','Economy (GDP per Capita)':gdpname,'Family':socialname,'Health (Life Expectancy)':lifeexpectancyname,'Freedom':freedomname, 'Generosity':generocityname, 'Trust (Government Corruption)':corruptionname}, inplace = True)
data16['year']='2016'

# %%
data16
# Out:
#     Country name  Score  Explained by: Log GDP per capita  \
# 0        Denmark  7.526                           1.44178
# 1    Switzerland  7.509                           1.52733
# 2        Iceland  7.501                           1.42666
# 3         Norway  7.498                           1.57744
# 4        Finland  7.413                           1.40598
# ..           ...    ...                               ...
# 152        Benin  3.484                           0.39499
# 153  Afghanistan  3.360                           0.38227
# 154         Togo  3.303                           0.28123
# 155        Syria  3.069                           0.74719
# 156      Burundi  2.905                           0.06831
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.16374                                0.79504
# 1                         1.14524                                0.86303
# ...

# %%
data15.drop(data15.columns.difference(['Country','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom', 'Generosity', 'Trust (Government Corruption)']), 1, inplace=True)
data15.rename(columns = {'Country':'Country name','Happiness Score':'Score','Economy (GDP per Capita)':gdpname,'Family':socialname,'Health (Life Expectancy)':lifeexpectancyname,'Freedom':freedomname, 'Generosity':generocityname, 'Trust (Government Corruption)':corruptionname}, inplace = True)
data15['year']='2015'

# %%
data15.head()
# Out:
#   Country name  Score  Explained by: Log GDP per capita  \
# 0  Switzerland  7.587                           1.39651
# 1      Iceland  7.561                           1.30232
# 2      Denmark  7.527                           1.32548
# 3       Norway  7.522                           1.45900
# 4       Canada  7.427                           1.32629
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                       1.34951                                0.94143
# 1                       1.40223                                0.94784
# 2                       1.36058                                0.87464
# 3                       1.33095                                0.88521
# 4                       1.32261                                0.90563
#
#    Explained by: Freedom to make life choices  \
# 0                                     0.66557
# 1                                     0.62877
# 2                                     0.64938
# ...

# %%
data15
# Out:
#     Country name  Score  Explained by: Log GDP per capita  \
# 0    Switzerland  7.587                           1.39651
# 1        Iceland  7.561                           1.30232
# 2        Denmark  7.527                           1.32548
# 3         Norway  7.522                           1.45900
# 4         Canada  7.427                           1.32629
# ..           ...    ...                               ...
# 153       Rwanda  3.465                           0.22208
# 154        Benin  3.340                           0.28665
# 155        Syria  3.006                           0.66320
# 156      Burundi  2.905                           0.01530
# 157         Togo  2.839                           0.20868
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.34951                                0.94143
# 1                         1.40223                                0.94784
# ...

# %%
data16
# Out:
#     Country name  Score  Explained by: Log GDP per capita  \
# 0        Denmark  7.526                           1.44178
# 1    Switzerland  7.509                           1.52733
# 2        Iceland  7.501                           1.42666
# 3         Norway  7.498                           1.57744
# 4        Finland  7.413                           1.40598
# ..           ...    ...                               ...
# 152        Benin  3.484                           0.39499
# 153  Afghanistan  3.360                           0.38227
# 154         Togo  3.303                           0.28123
# 155        Syria  3.069                           0.74719
# 156      Burundi  2.905                           0.06831
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.16374                                0.79504
# 1                         1.14524                                0.86303
# ...

# %%
frames = [data21, data20, data19, data18, data17, data16, data15]

# %%
result = pd.concat(frames, sort=True)

# %%
result
# Out:
#     Country name  Explained by: Freedom to make life choices  \
# 0        Finland                                     0.69100
# 1        Denmark                                     0.68600
# 2    Switzerland                                     0.65300
# 3        Iceland                                     0.69800
# 4    Netherlands                                     0.64700
# ..           ...                                         ...
# 153       Rwanda                                     0.59201
# 154        Benin                                     0.48450
# 155        Syria                                     0.15684
# 156      Burundi                                     0.11850
# 157         Togo                                     0.36453
#
#      Explained by: Generosity  Explained by: Healthy life expectancy  \
# 0                     0.12400                                0.74100
# 1                     0.20800                                0.76300
# ...

# %%
result=result.interpolate()

# %%
result
# Out:
#     Country name  Explained by: Freedom to make life choices  \
# 0        Finland                                     0.69100
# 1        Denmark                                     0.68600
# 2    Switzerland                                     0.65300
# 3        Iceland                                     0.69800
# 4    Netherlands                                     0.64700
# ..           ...                                         ...
# 153       Rwanda                                     0.59201
# 154        Benin                                     0.48450
# 155        Syria                                     0.15684
# 156      Burundi                                     0.11850
# 157         Togo                                     0.36453
#
#      Explained by: Generosity  Explained by: Healthy life expectancy  \
# 0                     0.12400                                0.74100
# 1                     0.20800                                0.76300
# ...

# %%
import country_converter as coco

# %%
result['Country name'].unique()
# Out:
# array(['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands',
#        'Norway', 'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
#        'Australia', 'Israel', 'Germany', 'Canada', 'Ireland',
#        'Costa Rica', 'United Kingdom', 'Czech Republic', 'United States',
#        'Belgium', 'France', 'Bahrain', 'Malta',
#        'Taiwan Province of China', 'United Arab Emirates', 'Saudi Arabia',
#        'Spain', 'Italy', 'Slovenia', 'Guatemala', 'Uruguay', 'Singapore',
#        'Kosovo', 'Slovakia', 'Brazil', 'Mexico', 'Jamaica', 'Lithuania',
#        'Cyprus', 'Estonia', 'Panama', 'Uzbekistan', 'Chile', 'Poland',
#        'Kazakhstan', 'Romania', 'Kuwait', 'Serbia', 'El Salvador',
#        'Mauritius', 'Latvia', 'Colombia', 'Hungary', 'Thailand',
#        'Nicaragua', 'Japan', 'Argentina', 'Portugal', 'Honduras',
#        'Croatia', 'Philippines', 'South Korea', 'Peru',
#        'Bosnia and Herzegovina', 'Moldova', 'Ecuador', 'Kyrgyzstan',
# ...

# %%
iso3_codes = coco.convert(names=result['Country name'].unique(), to='ISO3')
# Out:
# More then one regular expression match for ['Finland' 'Denmark' 'Switzerland' 'Iceland' 'Netherlands' 'Norway'
#  'Sweden' 'Luxembourg' 'New Zealand' 'Austria' 'Australia' 'Israel'
#  'Germany' 'Canada' 'Ireland' 'Costa Rica' 'United Kingdom'
#  'Czech Republic' 'United States' 'Belgium' 'France' 'Bahrain' 'Malta'
#  'Taiwan Province of China' 'United Arab Emirates' 'Saudi Arabia' 'Spain'
#  'Italy' 'Slovenia' 'Guatemala' 'Uruguay' 'Singapore' 'Kosovo' 'Slovakia'
#  'Brazil' 'Mexico' 'Jamaica' 'Lithuania' 'Cyprus' 'Estonia' 'Panama'
#  'Uzbekistan' 'Chile' 'Poland' 'Kazakhstan' 'Romania' 'Kuwait' 'Serbia'
#  'El Salvador' 'Mauritius' 'Latvia' 'Colombia' 'Hungary' 'Thailand'
#  'Nicaragua' 'Japan' 'Argentina' 'Portugal' 'Honduras' 'Croatia'
#  'Philippines' 'South Korea' 'Peru' 'Bosnia and Herzegovina' 'Moldova'
#  'Ecuador' 'Kyrgyzstan' 'Greece' 'Bolivia' 'Mongolia' 'Paraguay'
#  'Montenegro' 'Dominican Republic' 'North Cyprus' 'Belarus' 'Russia'
# ...

# %%
result
# Out:
#     Country name  Explained by: Freedom to make life choices  \
# 0        Finland                                     0.69100
# 1        Denmark                                     0.68600
# 2    Switzerland                                     0.65300
# 3        Iceland                                     0.69800
# 4    Netherlands                                     0.64700
# ..           ...                                         ...
# 153       Rwanda                                     0.59201
# 154        Benin                                     0.48450
# 155        Syria                                     0.15684
# 156      Burundi                                     0.11850
# 157         Togo                                     0.36453
#
#      Explained by: Generosity  Explained by: Healthy life expectancy  \
# 0                     0.12400                                0.74100
# 1                     0.20800                                0.76300
# ...

# %%
result['code'] = result['Country name'].apply(coco.convert)

# %%
result
# Out:
#     Country name  Explained by: Freedom to make life choices  \
# 0        Finland                                     0.69100
# 1        Denmark                                     0.68600
# 2    Switzerland                                     0.65300
# 3        Iceland                                     0.69800
# 4    Netherlands                                     0.64700
# ..           ...                                         ...
# 153       Rwanda                                     0.59201
# 154        Benin                                     0.48450
# 155        Syria                                     0.15684
# 156      Burundi                                     0.11850
# 157         Togo                                     0.36453
#
#      Explained by: Generosity  Explained by: Healthy life expectancy  \
# 0                     0.12400                                0.74100
# 1                     0.20800                                0.76300
# ...

# %%
result=result.replace(0,np.nan)

# %%
result=result.interpolate()

# %%
result
# Out:
#     Country name  Explained by: Freedom to make life choices  \
# 0        Finland                                     0.69100
# 1        Denmark                                     0.68600
# 2    Switzerland                                     0.65300
# 3        Iceland                                     0.69800
# 4    Netherlands                                     0.64700
# ..           ...                                         ...
# 153       Rwanda                                     0.59201
# 154        Benin                                     0.48450
# 155        Syria                                     0.15684
# 156      Burundi                                     0.11850
# 157         Togo                                     0.36453
#
#      Explained by: Generosity  Explained by: Healthy life expectancy  \
# 0                     0.12400                                0.74100
# 1                     0.20800                                0.76300
# ...

# %%
result=result.replace(0,np.nan)

# %%
result=result.interpolate()

# %%
result.to_csv(os.getcwd()+'/Full Data.csv')

# %%
data212=data21.copy()

# %%
data212.drop(data212.columns.difference(['Country name','Score','year']), 1, inplace=True)

# %%
data212
# Out:
#     Country name  Score  year
# 0        Finland  7.842  2021
# 1        Denmark  7.620  2021
# 2    Switzerland  7.571  2021
# 3        Iceland  7.554  2021
# 4    Netherlands  7.464  2021
# ..           ...    ...   ...
# 144      Lesotho  3.512  2021
# 145     Botswana  3.467  2021
# 146       Rwanda  3.415  2021
# 147     Zimbabwe  3.145  2021
# 148  Afghanistan  2.523  2021
#
# [149 rows x 3 columns]

# %%
frames=[data212,concated]

# %%
concated = pd.concat(frames)

# %%
#concated["year"] = pd.to_numeric(concated["year"])

# %%
#concated=concated.sort_values(by=['year'], ascending=False)

# %%
concated
# Out:
#     Country name  Score  year  Unnamed: 0
# 0        Finland  7.842  2021         NaN
# 1        Denmark  7.620  2021         NaN
# 2    Switzerland  7.571  2021         NaN
# 3        Iceland  7.554  2021         NaN
# 4    Netherlands  7.464  2021         NaN
# ..           ...    ...   ...         ...
# 930       Rwanda  3.465  2015       153.0
# 931        Benin  3.340  2015       154.0
# 932        Syria  3.006  2015       155.0
# 933      Burundi  2.905  2015       156.0
# 934         Togo  2.839  2015       157.0
#
# [1084 rows x 4 columns]

# %%
concated.to_csv(os.getcwd()+'/concated.csv')
